# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('Cancer cell lines')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references      organism                           pref_name  score  \
# 0                 []          None                   cancer cell lines   29.0
# 1                 []          None              cancer cell lines (55)   26.0
# 2                 []  Homo sapiens            Breast cancer cell lines   26.0
# 3                 []  Homo sapiens  KATO III stomach cancer cell lines   21.0
# 4                 []          None                    AH125 cell lines   17.0
# ..               ...           ...                                 ...    ...
# 776               []  Homo sapiens             Forkhead box protein M1    1.0
# 777               []  Homo sapiens                     Ephrin receptor    0.0
# 778               []  Homo sapiens      3',5'-cyclic phosphodiesterase    0.0
# 779               []  Homo sapiens                             Laminin    0.0
# 780               []  Homo sapiens                             Caspase    0.0
#
#      species_group_flag target_chembl_id  \
# 0                 False     CHEMBL614375
# 1                 False     CHEMBL614376
# 2                 False     CHEMBL614788
# 3                 False     CHEMBL612700
# 4                 False     CHEMBL614569
# ..                  ...              ...
# 776               False    CHEMBL4739852
# 777               False    CHEMBL2363043
# 778               False    CHEMBL2363066
# 779               False    CHEMBL2364187
# 780               False    CHEMBL3831289
#
#                                      target_components            target_type  \
# 0                                                   []              CELL-LINE
# 1                                                   []              CELL-LINE
# 2                                                   []              CELL-LINE
# 3                                                   []              CELL-LINE
# 4                                                   []              CELL-LINE
# ..                                                 ...                    ...
# 776  [{'accession': 'Q08050', 'component_descriptio...         SINGLE PROTEIN
# 777  [{'accession': 'P29317', 'component_descriptio...         PROTEIN FAMILY
# 778  [{'accession': 'O76074', 'component_descriptio...         PROTEIN FAMILY
# 779  [{'accession': 'P25391', 'component_descriptio...  PROTEIN COMPLEX GROUP
# 780  [{'accession': 'P49662', 'component_descriptio...         PROTEIN FAMILY
#
#      tax_id
# 0       NaN
# 1       NaN
# 2    9606.0
# 3    9606.0
# 4       NaN
# ..      ...
# 776  9606.0
# 777  9606.0
# 778  9606.0
# 779  9606.0
# 780  9606.0
#
# [781 rows x 9 columns]

# %%
selected_target = targets.target_chembl_id[776]
selected_target
# Out:
# 'CHEMBL4739852'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#   activity_comment  activity_id  \
# 0             None     22907722
# 1             None     22907723
#
#                                  activity_properties assay_chembl_id  \
# 0  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4733556
# 1  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4733556
#
#                                    assay_description assay_type  \
# 0  Binding affinity to recombinant FOXM1 DBD (unk...          B
# 1  Binding affinity to recombinant FOXM1 DBD (unk...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000019
# 1                    None                   None  BAO_0000190  BAO_0000019
#
#    ... target_organism         target_pref_name target_tax_id text_value  \
# 0  ...    Homo sapiens  Forkhead box protein M1          9606       None
# 1  ...    Homo sapiens  Forkhead box protein M1          9606       None
#
#    toid  type  units    uo_units upper_value  value
# 0  None  IC50     uM  UO_0000065        None  50.54
# 1  None  IC50     uM  UO_0000065        None  122.4
#
# [2 rows x 45 columns]
